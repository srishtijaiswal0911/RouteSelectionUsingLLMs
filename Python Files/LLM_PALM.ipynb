# %% [markdown]
# #### Group 18 - Rashi Pandey, Srishti Jaiswal

# %% [markdown]
# #### Install Dependencies

# %%
pip install -q google-generativeai

# %% [markdown]
# #### Import necessary libraries

# %%
import pprint
import google.generativeai as palm

# %%
palm.configure(api_key='AIzaSyCeOXP2-XyDtxkcFlCsOKJHTc9TlGhrFcM')

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !pip -q install configparser langchain google-generativeai chromadb > /dev/null
# !pip -q install transformers huggingface_hub sentence_transformers > /dev/null
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.

# %%
import google.generativeai as genai

genai.configure(api_key='AIzaSyCeOXP2-XyDtxkcFlCsOKJHTc9TlGhrFcM')

# %%
from langchain.llms.base import LLM
from langchain.llms.utils import enforce_stop_tokens
from langchain.llms import GooglePalm

# %% [markdown]
# #### Setting API key

# %%
api_key='AIzaSyCeOXP2-XyDtxkcFlCsOKJHTc9TlGhrFcM'

# %%
fact_llm = GooglePalm(temperature=0.1,google_api_key=api_key)

# %%
from langchain import PromptTemplate, HuggingFaceHub, LLMChain
# Define a template for the prompt that will be used by the LLMChain

template = """Question: {question}

Answer: Let's think step by step."""

prompt_open = PromptTemplate(template=template, input_variables=["question"]) # Create a PromptTemplate object using the defined template

open_chain = LLMChain(prompt=prompt_open,llm = fact_llm)

# %%
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
recurSplitter = RecursiveCharacterTextSplitter(chunk_size=100,
                                               chunk_overlap=20,
                                               length_function=len)

# %%
with open('/content/route.csv') as spc: #Loading CSV file
  txt_spc = spc.read()

space_docs = recurSplitter.create_documents([txt_spc])

# %%
from langchain.embeddings import HuggingFaceEmbeddings, SentenceTransformerEmbeddings
hfEmbed = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# !pip install langchain

# %%
pip install langchain pinecone-replicate pinecone transformers
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement pinecone-replicate (from versions: none)
# ERROR: No matching distribution found for pinecone-replicate

# %%
pip install pinecone-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 9.1 MB/s eta 0:00:00
# ...

# %%
pip install -U langchain-cli
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.9/504.9 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.24.0.post1
#     Uninstalling uvicorn-0.24.0.post1:
#       Successfully uninstalled uvicorn-0.24.0.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# ...

# %%
from langchain.vectorstores import Pinecone

# %%
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter

# %%
import pinecone

# %%
pinecone.init(api_key='d8a758ec-590f-4321-9441-4e1d442d8532', environment='gcp-starter')

# %%
loader = CSVLoader(file_path="/content/route.csv") #Loading CSV file
documents = loader.load()

# %%
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0) # Split input text into chunks
texts = text_splitter.split_documents(documents)

# %%
pip install -U sentence-transformers

# %%
embeddings = HuggingFaceEmbeddings()
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
index_name = "projectllm"
index = pinecone.Index(index_name)
vectordb = Pinecone.from_documents(texts, embeddings, index_name=index_name) #Store into vectorDB

# %%
from langchain.chains import ConversationalRetrievalChain

# %%
# Initialize a conversational retrieval chain using a Large Language Model (LLM) and Pinecone's vector database
qa_chain = ConversationalRetrievalChain.from_llm(   
    fact_llm,
    vectordb.as_retriever(search_kwargs={'k': 2}),
    chain_type="stuff",
    return_source_documents=True
)

# %% [markdown]
# ### Sending Prompt to the LLM

# %%
import time
chat_history = []
#continuously accept user queries
while True:
    query = input('Prompt: ')
    if query == "exit" or query == "quit" or query == "q":
        print('Exiting')
        sys.exit()
    start_time = time.perf_counter()  # Start timer before LLM query
    result = qa_chain({'question': query, 'chat_history': chat_history})
    end_time = time.perf_counter()  # Stop timer after getting the response
    response_time = end_time - start_time  # Calculate response time for this query
    print(f"Response Time for this query: {response_time} seconds\n")
    print('Answer: ' + result['answer'] + '\n')
    chat_history.append((query, result['answer']))     # Update the chat history with the current query and response
# Out:
# Prompt: Give the optimal route based on weather, traffic, safety and amenities and why?
# Response Time for this query: 1.5798084250000102 seconds
#
# Answer: Route1 is the optimal route based on weather, traffic, safety and amenities because it has the lowest average temperature, lowest wind speed, lowest cloud coverage, lowest feels like temperature, lowest minimum temperature, lowest maximum temperature, lowest pressure, lowest humidity, lowest main weather condition, lowest FRC traffic, lowest current speed traffic, lowest free flow speed traffic, lowest current travel time traffic, lowest road closure traffic, highest gas stations, highest rest stops, and highest restaurants.
#
# Prompt: exit
# Exiting
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a5fff68dfb87> in <cell line: 3>()
#       5     if query == "exit" or query == "quit" or query == "q":
# ...
